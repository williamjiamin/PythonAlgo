# %% [markdown]
# Created by william from lexueoude.com. 更多正版技术视频讲解，公众号：乐学FinTech

# %% [markdown]
# Array Sequences
#
# 在Python中支持Index的一系列数据类型：
# 1.List [elem1,elem2,elem3....]
# 2.Tuple (elem1,elem2,elem3...)
# *3.String ""
# ...
# 类比成"查字典"

# %%
from IPython.display import Image
Image(filename='3.Array_Sequence_2.png')

# %%
from IPython.display import Image
Image(filename='3.Array_Sequence_2.png')

# %%
from IPython.display import Image
Image(filename='3.Array_Sequence_3.png')

# %%
import sys
n=100
test_data = []
for i in range(n):
    x = len(test_data)
    y = sys.getsizeof(test_data)
    
    print('The Length of the data list is :{0:3d};The size in memory (bytes) is :{1:4d}'.format(x,y))
    test_data.append(n)
# Out:
# The Length of the data list is :  0;The size in memory (bytes) is :  56
# The Length of the data list is :  1;The size in memory (bytes) is :  88
# The Length of the data list is :  2;The size in memory (bytes) is :  88
# The Length of the data list is :  3;The size in memory (bytes) is :  88
# The Length of the data list is :  4;The size in memory (bytes) is :  88
# The Length of the data list is :  5;The size in memory (bytes) is : 120
# The Length of the data list is :  6;The size in memory (bytes) is : 120
# The Length of the data list is :  7;The size in memory (bytes) is : 120
# The Length of the data list is :  8;The size in memory (bytes) is : 120
# The Length of the data list is :  9;The size in memory (bytes) is : 184
# The Length of the data list is : 10;The size in memory (bytes) is : 184
# The Length of the data list is : 11;The size in memory (bytes) is : 184
# The Length of the data list is : 12;The size in memory (bytes) is : 184
# ...

# %%
from IPython.display import Image
Image(filename='3.Array_Sequence_4.png')
